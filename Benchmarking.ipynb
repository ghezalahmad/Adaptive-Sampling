# %% [markdown]
# ### Experiment

# %%
# Assuming the previous data was for RF + GPR, and the new data is for LR + GPR
# Combining both sets of data for RF + GPR and LR + GPR
import matplotlib.pyplot as plt
import numpy as np
# Data from RF + GPR experiments (provided earlier)
rf_gpr_data = {
    'RF+GPR Experiment 17 - Initial 4': {
        'Total Samples': 26,
        'Corrosion Points': 7
    },
    'RF+GPR Experiment 17 - Initial 20': {
        'Total Samples': 44,
        'Corrosion Points': 6
    },
    'RF+GPR Experiment 18 - Initial 4': {
        'Total Samples': 27,
        'Corrosion Points': 4
    },
    'RF+GPR Experiment 18 - Initial 20': {
        'Total Samples': 40,
        'Corrosion Points': 3
    }
}

# Data from LR + GPR experiments (provided just now)
lr_gpr_data = {
    'LR+GPR Experiment 17 - Initial 4': {
        'Total Samples': 28,
        'Corrosion Points': 9
    },
    'LR+GPR Experiment 17 - Initial 20': {
        'Total Samples': 43,
        'Corrosion Points': 7
    },
    'LR+GPR Experiment 18 - Initial 4': {
        'Total Samples': 27,
        'Corrosion Points': 5
    },
    'LR+GPR Experiment 18 - Initial 20': {
        'Total Samples': 43,
        'Corrosion Points': 6
    }
}

# Combine both dictionaries into a single one for plotting
combined_data = {**rf_gpr_data, **lr_gpr_data}

# Set up the bar plot configuration
labels = list(combined_data.keys())
total_samples = [data['Total Samples'] for data in combined_data.values()]
corrosion_points = [data['Corrosion Points'] for data in combined_data.values()]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 6))  # Increased figure size for clarity

# Generate the bars for total samples
rects1 = ax.bar(x - width/2, total_samples, width, label='Total Samples')

# Generate the bars for corrosion points
rects2 = ax.bar(x + width/2, corrosion_points, width, label='Corrosion Points')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Counts')
ax.set_title('Comparison of Total Samples and Corrosion Points Detected across Experiments')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=90)  # Rotate labels to prevent overlap
ax.legend()

# Call the function to label the heights
autolabel(rects1)
autolabel(rects2)

# Adjust the layout
fig.tight_layout()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 72
#      69 ax.legend()
#      71 # Call the function to label the heights
# ---> 72 autolabel(rects1)
#      73 autolabel(rects2)
#      75 # Adjust the layout
#
# NameError: name 'autolabel' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
experiments = ['Experiment 17 - Initial 4', 'Experiment 17 - Initial 20',
               'Experiment 18 - Initial 4', 'Experiment 18 - Initial 20']

# RF+GPR results (from the first set of data provided)
rf_gpr_samples = [26, 44, 27, 40]
rf_gpr_corrosion = [7, 6, 4, 3]

# LR+GPR results (from the second set of data provided)
lr_gpr_samples = [28, 43, 27, 43]
lr_gpr_corrosion = [9, 7, 5, 6]

# Set up the bar plot configuration
x = np.arange(len(experiments))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 6))

# Generate the bars for RF+GPR total samples
rects1 = ax.bar(x - width/2, rf_gpr_samples, width, label='RF+GPR Total Samples')

# Generate the bars for RF+GPR corrosion points
rects2 = ax.bar(x - width/2, rf_gpr_corrosion, width, label='RF+GPR Corrosion Points', bottom=rf_gpr_samples)

# Generate the bars for LR+GPR total samples
rects3 = ax.bar(x + width/2, lr_gpr_samples, width, label='LR+GPR Total Samples')

# Generate the bars for LR+GPR corrosion points
rects4 = ax.bar(x + width/2, lr_gpr_corrosion, width, label='LR+GPR Corrosion Points', bottom=lr_gpr_samples)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Counts')
ax.set_title('Total Samples Evaluated and Corrosion Points Detected')
ax.set_xticks(x)
ax.set_xticklabels(experiments)
ax.legend()

# Function to attach a text label above each bar, displaying its height
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# Call the function to label the heights
autolabel(rects1)
autolabel(rects3)

# Adjust the layout
fig.tight_layout()
plt.savefig('plot1.png', dpi=300)  # Saves the figure as 'plot.png' with 300 DPI

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Data for plotting (corrected)
experiments = ['Experiment 17 - Initial 4', 'Experiment 17 - Initial 20',
               'Experiment 18 - Initial 4', 'Experiment 18 - Initial 20']

# Results from RF+GPR
rf_gpr = {
    'Samples': [26, 44, 27, 40],
    'Corrosion': [7, 6, 4, 3]
}

# Results from LR+GPR
lr_gpr = {
    'Samples': [28, 43, 27, 43],
    'Corrosion': [9, 7, 5, 6]
}

# Plot configuration
bar_width = 0.35
index = np.arange(len(experiments))

# Initialize the plot
fig, ax = plt.subplots(figsize=(14, 8))

# Stacked bars for RF+GPR
rf_samples_bars = ax.bar(index - bar_width/2, rf_gpr['Samples'], bar_width, label='RF+GPR Samples')
rf_corrosion_bars = ax.bar(index - bar_width/2, rf_gpr['Corrosion'], bar_width, bottom=rf_gpr['Samples'], label='RF+GPR Corrosion')

# Stacked bars for LR+GPR
lr_samples_bars = ax.bar(index + bar_width/2, lr_gpr['Samples'], bar_width, label='LR+GPR Samples')
lr_corrosion_bars = ax.bar(index + bar_width/2, lr_gpr['Corrosion'], bar_width, bottom=lr_gpr['Samples'], label='LR+GPR Corrosion')

# Labels, title, and custom x-axis tick labels
ax.set_ylabel('Count')
ax.set_title('Samples and Corrosion Points Detected by Model and Experiment')
ax.set_xticks(index)
ax.set_xticklabels(experiments)
ax.legend()

# Text labels above the bars
def label_bars(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

label_bars(rf_samples_bars)
label_bars(lr_samples_bars)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
models = ['RF + GPR', 'LR + GPR']
experiments = ['Experiment 17', 'Experiment 18']
initial_samples = ['4', '20']
metrics = ['Total unique samples evaluated', 'Total corrosion points detected']

# Data for plotting
data = {
    ('RF + GPR', 'Experiment 17', '4'): [26, 7],
    ('RF + GPR', 'Experiment 17', '20'): [44, 6],
    ('RF + GPR', 'Experiment 18', '4'): [27, 4],
    ('RF + GPR', 'Experiment 18', '20'): [40, 3],
    ('LR + GPR', 'Experiment 17', '4'): [28, 9],
    ('LR + GPR', 'Experiment 17', '20'): [43, 7],
    ('LR + GPR', 'Experiment 18', '4'): [27, 5],
    ('LR + GPR', 'Experiment 18', '20'): [43, 6]
}

n_groups = len(metrics)
fig, ax = plt.subplots(figsize=(10, 6))

index = np.arange(n_groups)
bar_width = 0.1
opacity = 0.8

for i, model in enumerate(models):
    for j, experiment in enumerate(experiments):
        for k, initial_sample in enumerate(initial_samples):
            offset = (i * len(experiments) * len(initial_samples) + j * len(initial_samples) + k) * bar_width
            vals = data[(model, experiment, initial_sample)]
            plt.bar(index + offset, vals, bar_width, alpha=opacity, label=f'{model} - {experiment} - Initial Sample {initial_sample}')

plt.xlabel('Metric')
plt.ylabel('Values')
plt.title('Comparative Analysis Across Models, Experiments, and Initial Samples')
plt.xticks(index + bar_width, metrics)
plt.legend()

plt.tight_layout()
plt.show()
plt.savefig('plot.png', dpi=300)  # Saves the figure as 'plot.png' with 300 DPI

# %%
# Now we will create a stacked bar plot using matplotlib
import numpy as np
# First, let's create a DataFrame with the necessary structure
stacked_data = pd.DataFrame({
    'Experiment': ['17 - Initial 4', '17 - Initial 20', '18 - Initial 4', '18 - Initial 20'] * 2,
    'Model': ['RF+GPR'] * 4 + ['LR+GPR'] * 4,
    'Total Samples': [26, 44, 27, 40, 28, 43, 27, 43],
    'Corrosion Points': [7, 6, 4, 3, 9, 7, 5, 6]
})

# Calculate the non-corrosion samples for the stacked bar
stacked_data['Non-Corrosion Samples'] = stacked_data['Total Samples'] - stacked_data['Corrosion Points']

# Set up the bar plot configuration
labels = ['17 - Initial 4', '17 - Initial 20', '18 - Initial 4', '18 - Initial 20']
rf_samples = stacked_data[stacked_data['Model'] == 'RF+GPR']['Non-Corrosion Samples']
rf_corrosion = stacked_data[stacked_data['Model'] == 'RF+GPR']['Corrosion Points']
lr_samples = stacked_data[stacked_data['Model'] == 'LR+GPR']['Non-Corrosion Samples']
lr_corrosion = stacked_data[stacked_data['Model'] == 'LR+GPR']['Corrosion Points']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

# Generate the bars for RF+GPR and LR+GPR
ax.bar(x - width/2, rf_samples, width, label='RF+GPR Non-Corrosion Samples', color='skyblue')
ax.bar(x - width/2, rf_corrosion, width, label='RF+GPR Corrosion Points', bottom=rf_samples, color='blue')
ax.bar(x + width/2, lr_samples, width, label='LR+GPR Non-Corrosion Samples', color='lightgreen')
ax.bar(x + width/2, lr_corrosion, width, label='LR+GPR Corrosion Points', bottom=lr_samples, color='green')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Samples')
ax.set_title('Total Samples and Corrosion Points Detected by Model and Experiment')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Annotate the total samples above each bar
for i in x:
    ax.text(i - width/2, rf_samples.iloc[i] + rf_corrosion.iloc[i], str(rf_samples.iloc[i] + rf_corrosion.iloc[i]), ha='center', va='bottom')
    ax.text(i + width/2, lr_samples.iloc[i] + lr_corrosion.iloc[i], str(lr_samples.iloc[i] + lr_corrosion.iloc[i]), ha='center', va='bottom')

# Show the plot
plt.show()

# %%
import pandas as pd

# Classification report data
data = {
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Support'],
    'Class 0 (No Corrosion)': [0.99, 0.99, 0.99, 23880],
    'Class 1 (Corrosion)': [0.73, 0.65, 0.69, 744],
    'Accuracy': ['', '', '', 0.98],
    'Macro Avg': [0.86, 0.82, 0.84, 24624],
    'Weighted Avg': [0.98, 0.98, 0.98, 24624]
}

# Creating a DataFrame
classification_report_df = pd.DataFrame(data)

# Displaying the DataFrame
classification_report_df
# Out:
#       Metric  Class 0 (No Corrosion)  Class 1 (Corrosion) Accuracy  Macro Avg  \
# 0  Precision                    0.99                 0.73                0.86
# 1     Recall                    0.99                 0.65                0.82
# 2   F1-Score                    0.99                 0.69                0.84
# 3    Support                23880.00               744.00     0.98   24624.00
#
#    Weighted Avg
# 0          0.98
# 1          0.98
# 2          0.98
# 3      24624.00

# %%
import matplotlib.pyplot as plt

# Convert the DataFrame to a table in a matplotlib figure
fig, ax = plt.subplots(figsize=(10, 6))  # Set figure size
ax.axis('tight')
ax.axis('off')
ax.table(cellText=classification_report_df.values,
         colLabels=classification_report_df.columns,
         cellLoc = 'center', 
         loc='center')

plt.savefig('RF_Classification_Report.png', dpi=300)  # Save the table as a PNG file with high resolution
plt.show()

# %%
# LR Classification report data
lr_data = {
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Support'],
    'Class 0 (No Corrosion)': [0.99, 0.99, 0.99, 23880],
    'Class 1 (Corrosion)': [0.63, 0.66, 0.64, 744],
    'Accuracy': ['', '', '', 0.98],
    'Macro Avg': [0.81, 0.82, 0.82, 24624],
    'Weighted Avg': [0.98, 0.98, 0.98, 24624]
}

# Creating a DataFrame for LR classification report
lr_classification_report_df = pd.DataFrame(lr_data)

# Displaying the DataFrame
lr_classification_report_df
# Out:
#       Metric  Class 0 (No Corrosion)  Class 1 (Corrosion) Accuracy  Macro Avg  \
# 0  Precision                    0.99                 0.63                0.81
# 1     Recall                    0.99                 0.66                0.82
# 2   F1-Score                    0.99                 0.64                0.82
# 3    Support                23880.00               744.00     0.98   24624.00
#
#    Weighted Avg
# 0          0.98
# 1          0.98
# 2          0.98
# 3      24624.00

# %%
import matplotlib.pyplot as plt

# Convert the DataFrame to a table in a matplotlib figure
fig, ax = plt.subplots(figsize=(10, 6))  # Set figure size
ax.axis('tight')
ax.axis('off')
ax.table(cellText=lr_classification_report_df.values,
         colLabels=lr_classification_report_df.columns,
         cellLoc = 'center', 
         loc='center')

plt.savefig('LR_Classification_Report.png', dpi=300)  # Save the table as a PNG file with high resolution
plt.show()

# %%
import pandas as pd
from docx import Document
from docx.shared import Pt

# RF Classification report data
rf_data = {
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Support', 'Accuracy', 'Macro Avg', 'Weighted Avg'],
    'RF Class 0 (No Corrosion)': ['0.99', '0.99', '0.99', '23880', '', '', ''],
    'RF Class 1 (Corrosion)': ['0.73', '0.65', '0.69', '744', '', '', ''],
    'RF Overall': ['', '', '', '', '0.98', '0.84', '0.98']
}

# LR Classification report data
lr_data = {
    'Metric': ['Precision', 'Recall', 'F1-Score', 'Support', 'Accuracy', 'Macro Avg', 'Weighted Avg'],
    'LR Class 0 (No Corrosion)': ['0.99', '0.99', '0.99', '23880', '', '', ''],
    'LR Class 1 (Corrosion)': ['0.63', '0.66', '0.64', '744', '', '', ''],
    'LR Overall': ['', '', '', '', '0.98', '0.82', '0.98']
}

# Convert the data to DataFrames
rf_df = pd.DataFrame(rf_data)
lr_df = pd.DataFrame(lr_data)

# Combine the RF and LR data into one DataFrame
combined_df = pd.concat([rf_df, lr_df.drop('Metric', axis=1)], axis=1)

# Create a new Word document
doc = Document()

# Add a title to the document
doc.add_heading('Combined Classification Report for RF and LR', level=1)

# Add the table to the Word document
table = doc.add_table(rows=1, cols=len(combined_df.columns))

# Set the style for the table
table.style = 'Table Grid'

# Populate the header row
hdr_cells = table.rows[0].cells
for i, col_name in enumerate(combined_df.columns):
    hdr_cells[i].text = col_name
    hdr_cells[i].paragraphs[0].runs[0].font.bold = True  # Make the header bold

# Add the rest of the data frame
for index, row in combined_df.iterrows():
    row_cells = table.add_row().cells
    for i, value in enumerate(row):
        row_cells[i].text = str(value)

# Adjust the font size for the entire table
for row in table.rows:
    for cell in row.cells:
        paragraphs = cell.paragraphs
        for paragraph in paragraphs:
            for run in paragraph.runs:
                run.font.size = Pt(10)

# Save the document
doc.save('combined_classification_report.docx')

# %%
import numpy as np

# Data for RF + GPR
rf_gpr_17 = [3, 4, 7, 1, 1, 3, 1, 4, 2, 2, 1, 2, 4, 4, 1]
rf_gpr_18 = [2, 1, 1, 1, 1, 2, 1, 2, 4, 1, 1, 1, 1, 4, 1]

# Data for LR + GPR
lr_gpr_17 = [1, 1, 1, 2, 1, 1, 1, 2, 2, 2, 3, 1, 1, 2, 1]
lr_gpr_18 = [2, 1, 1, 1, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2]

# Combine the results from Experiment 17 and 18
combined_rf_gpr = rf_gpr_17 + rf_gpr_18
combined_lr_gpr = lr_gpr_17 + lr_gpr_18

# Calculate the mean and standard deviation for RF + GPR
mean_rf_gpr = np.mean(combined_rf_gpr)
std_rf_gpr = np.std(combined_rf_gpr)

# Calculate the mean and standard deviation for LR + GPR
mean_lr_gpr = np.mean(combined_lr_gpr)
std_lr_gpr = np.std(combined_lr_gpr)

# Calculate the 90th percentile for RF + GPR and LR + GPR
quantile_90_rf_gpr = np.percentile(combined_rf_gpr, 90)
quantile_90_lr_gpr = np.percentile(combined_lr_gpr, 90)

(mean_rf_gpr, std_rf_gpr, quantile_90_rf_gpr), (mean_lr_gpr, std_lr_gpr, quantile_90_lr_gpr)
# Out:
# ((2.1333333333333333, 1.4772346537440226, 4.0),
#  (1.5666666666666667, 0.5587684871413402, 2.0))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the user
rf_gpr_data = [3, 4, 7, 1, 1, 3, 1, 4, 2, 2, 1, 2, 4, 4, 1, 2, 1, 1, 1, 1, 2, 1, 2, 4, 1, 1, 1, 1, 4, 1]
lr_gpr_data = [1, 1, 1, 2, 1, 1, 1, 2, 2, 2, 3, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2]

# Calculate the 50% and 90% probability of success (quantiles)
rf_gpr_50_quantile = np.quantile(rf_gpr_data, 0.5)
rf_gpr_90_quantile = np.quantile(rf_gpr_data, 0.9)
lr_gpr_50_quantile = np.quantile(lr_gpr_data, 0.5)
lr_gpr_90_quantile = np.quantile(lr_gpr_data, 0.9)

# Create distribution plot
plt.figure(figsize=(10,6))
plt.hist([rf_gpr_data, lr_gpr_data], bins=range(1, max(rf_gpr_data + lr_gpr_data) + 1), 
         alpha=0.5, label=['RF + GPR', 'LR + GPR'])

# Add quantile lines
plt.axvline(x=rf_gpr_50_quantile, color='blue', linestyle='dashed', linewidth=2, label='RF + GPR 50% prob. of success')
plt.axvline(x=rf_gpr_90_quantile, color='blue', linestyle='solid', linewidth=2, label='RF + GPR 90% prob. of success')

plt.axvline(x=lr_gpr_50_quantile, color='orange', linestyle='dashed', linewidth=2, label='LR + GPR 50% prob. of success')
plt.axvline(x=lr_gpr_90_quantile, color='orange', linestyle='solid', linewidth=2, label='LR + GPR 90% prob. of success')

# Labeling
plt.xlabel('Development cycles (number of iterations)')
plt.ylabel('Frequency')
plt.title('Distribution of Iterations for Corrosion Detection')
plt.legend()
plt.savefig('distribution_plot.png', dpi=300)
# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
rf_gpr_data = [3, 4, 7, 1, 1, 3, 1, 4, 2, 2, 1, 2, 4, 4, 1, 2, 1, 1, 1, 1, 2, 1, 2, 4, 1, 1, 1, 1, 4, 1]
lr_gpr_data = [1, 1, 1, 2, 1, 1, 1, 2, 2, 2, 3, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2]

# Combine the data
combined_data = rf_gpr_data + lr_gpr_data

# Calculate the mean, std and the 90th percentile
mean_value = np.mean(combined_data)
std_dev = np.std(combined_data)
percentile_90 = np.percentile(combined_data, 90)

# Prepare histogram data
bins = range(1, int(max(combined_data)) + 2)

# Plot the histogram
plt.hist([rf_gpr_data, lr_gpr_data], bins=bins, alpha=0.5, label=['RF + GPR', 'LR + GPR'], color=['blue', 'orange'])

# Plot the mean, std_dev, and percentile lines
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(mean_value + std_dev, color='green', linestyle='dashed', linewidth=1, label='Mean + Std Dev')
plt.axvline(percentile_90, color='purple', linestyle='solid', linewidth=1, label='90th Percentile')

# Add labels and legend
plt.xlabel('Development Cycles')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.title('Distribution of Development Cycles for Corrosion Detection')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for RF + GPR and LR + GPR
rf_gpr_data = [3, 4, 7, 1, 1, 3, 1, 4, 2, 2, 1, 2, 4, 4, 1, 2, 1, 1, 1, 1, 2, 1, 2, 4, 1, 1, 1, 1, 4, 1]
lr_gpr_data = [1, 1, 1, 2, 1, 1, 1, 2, 2, 2, 3, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2]

# Calculations for RF + GPR
rf_mean = np.median(rf_gpr_data)
rf_std = np.std(rf_gpr_data)
rf_90_quantile = np.quantile(rf_gpr_data, 0.9)

# Calculations for LR + GPR
lr_mean = np.median(lr_gpr_data)
lr_std = np.std(lr_gpr_data)
lr_90_quantile = np.quantile(lr_gpr_data, 0.9)

# Creating the histogram for RF + GPR
plt.figure(figsize=(14, 7))

# RF + GPR Histogram
plt.subplot(1, 2, 1)
plt.hist(rf_gpr_data, bins=np.arange(0.5, max(rf_gpr_data)+1.5), color='skyblue', alpha=0.7)
plt.axvline(rf_mean, color='k', linestyle='dashed', linewidth=1, label=f'Mean = {rf_mean:.2f}')
plt.axvline(rf_90_quantile, color='r', linestyle='dashed', linewidth=1, label=f'90% Quantile = {rf_90_quantile:.2f}')
plt.title('RF + GPR Iterations Distribution')
plt.xlabel('Number of Iterations')
plt.ylabel('Frequency')
plt.xticks(np.arange(1, max(rf_gpr_data)+1))
plt.legend()

# LR + GPR Histogram
plt.subplot(1, 2, 2)
plt.hist(lr_gpr_data, bins=np.arange(0.5, max(lr_gpr_data)+1.5), color='yellow', alpha=0.7)
plt.axvline(lr_mean, color='k', linestyle='dashed', linewidth=1, label=f'Mean = {lr_mean:.2f}')
plt.axvline(lr_90_quantile, color='r', linestyle='dashed', linewidth=1, label=f'90% Quantile = {lr_90_quantile:.2f}')
plt.title('LR + GPR Iterations Distribution')
plt.xlabel('Number of Iterations')
plt.ylabel('Frequency')
plt.xticks(np.arange(1, max(lr_gpr_data)+1))
plt.legend()
plt.savefig('distribution_plot.png', dpi=300)
# Show plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# Load and preprocess the data
data = pd.read_excel("open_crosion.xlsx")
experiment_17_data = data[data['Experiment'] == 18]

# Adjust the coordinates to fit the grid
experiment_17_data['X-Coordinate_Adjusted'] = (experiment_17_data['X-Coordinate'] / 10).round().astype(int)
experiment_17_data['Y-Coordinate_Adjusted'] = (experiment_17_data['Y-Coordinate'] / 10).round().astype(int)
# Out:
# Corrosion found at iteration 2 at coordinates (60.0cm, 50.0cm)
# C:\Users\gzia\AppData\Local\Temp\ipykernel_11684\3550860501.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   experiment_17_data['X-Coordinate_Adjusted'] = (experiment_17_data['X-Coordinate'] / 10).round().astype(int)
# C:\Users\gzia\AppData\Local\Temp\ipykernel_11684\3550860501.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ## Random Sampling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# Load and preprocess the data
data = pd.read_excel("open_crosion.xlsx")
experiment_17_data = data[data['Experiment'] == 18]

# Adjust the coordinates to fit the grid
experiment_17_data['X-Coordinate_Adjusted'] = (experiment_17_data['X-Coordinate'] / 10).round().astype(int)
experiment_17_data['Y-Coordinate_Adjusted'] = (experiment_17_data['Y-Coordinate'] / 10).round().astype(int)

# Function to perform random sampling with visualization
def random_sampling_with_visualization(data, max_iterations=1000):
    sampled_points = []  # List to store sampled points
    corrosion_found = False
    
    for iteration in range(max_iterations):
        # Randomly select a point
        random_index = random.choice(data.index)
        random_point = data.loc[random_index]
        sampled_points.append((random_point['X-Coordinate_Adjusted'], random_point['Y-Coordinate_Adjusted']))
        
        # Check if the selected point is a corrosion point
        if random_point['Label'] == 1:
            print(f"Corrosion found at iteration {iteration + 1} at coordinates ({random_point['X-Coordinate_Adjusted'] * 10}cm, {random_point['Y-Coordinate_Adjusted'] * 10}cm)")
            corrosion_point = (random_point['X-Coordinate_Adjusted'], random_point['Y-Coordinate_Adjusted'])
            corrosion_found = True
            break
    
    if not corrosion_found:
        print(f"No corrosion found after {max_iterations} iterations.")
    
    # Visualization
    plt.figure(figsize=(10, 10))
    plt.grid(True)
    plt.title(f"Random Sampling in Experiment 17 - Iterations: {iteration + 1}")
    plt.xlabel("X-Coordinate (in adjusted units)")
    plt.ylabel("Y-Coordinate (in adjusted units)")

    # Plot all sampled points
    for point in sampled_points:
        plt.scatter(*point, color='blue', label='Sampled Point' if sampled_points.index(point) == 0 else "")

    # Highlight the corrosion point if found
    if corrosion_found:
        plt.scatter(*corrosion_point, color='red', label='Corrosion Point', s=100, edgecolors='black')

    plt.legend()
    plt.show()

    return iteration + 1  # Return the number of iterations required

# Perform random sampling with visualization on Experiment 17 data
iterations_required = random_sampling_with_visualization(experiment_17_data)
# Out:
# C:\Users\gzia\AppData\Local\Temp\ipykernel_11684\3141307504.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   experiment_17_data['X-Coordinate_Adjusted'] = (experiment_17_data['X-Coordinate'] / 10).round().astype(int)
# C:\Users\gzia\AppData\Local\Temp\ipykernel_11684\3141307504.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   experiment_17_data['Y-Coordinate_Adjusted'] = (experiment_17_data['Y-Coordinate'] / 10).round().astype(int)
# ...

# %%
# Calculate mean and standard deviation for the random_sampling_data
mean_random_sampling = np.mean(random_sampling_data)
std_dev_random_sampling = np.std(random_sampling_data)

mean_random_sampling, std_dev_random_sampling
# Out:
# (12.9, 10.684412322007548)

# %%
# Calculate mean and standard deviation for the random_sampling_data
mean_lhs_sampling_data = np.mean(lhs_sampling_data)
std_dev_lhs_sampling_data = np.std(lhs_sampling_data)

mean_lhs_sampling_data, std_dev_lhs_sampling_data
# Out:
# (15.9, 11.527792503337317)

# %% [markdown]
# ### Latine Hypercube Sampling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import qmc

# Load and preprocess the data
data = pd.read_excel("open_crosion.xlsx")
experiment_17_data = data[data['Experiment'] == 17]

# Adjust the coordinates to fit the grid
experiment_17_data['X-Coordinate_Adjusted'] = (experiment_17_data['X-Coordinate'] / 10).round().astype(int)
experiment_17_data['Y-Coordinate_Adjusted'] = (experiment_17_data['Y-Coordinate'] / 10).round().astype(int)
n_samples_total = 100  # Total number of samples to generate

def iterative_lhs_corrosion_detection_and_plot(data, n_samples):
    """Iteratively perform Latin Hypercube Sampling to detect corrosion and plot the process."""
    sampler = qmc.LatinHypercube(d=2)  # Initialize the LHS sampler for 2 dimensions
    samples = sampler.random(n=n_samples)  # Generate LHS samples

    # Scale the samples to the grid boundaries
    samples[:, 0] = qmc.scale(samples[:, [0]], [0], [13]).flatten()  # Scale for X-coordinate
    samples[:, 1] = qmc.scale(samples[:, [1]], [0], [9]).flatten()  # Scale for Y-coordinate
    samples = np.round(samples)  # Round to nearest grid point

    corrosion_found = False
    iteration = 0

    plt.figure(figsize=(13, 9))
    plt.grid(True)
    plt.title("Latin Hypercube Sampling in Experiment 17")
    plt.xlabel("X-Coordinate (cm)")
    plt.ylabel("Y-Coordinate (cm)")

    # Plot all points in the grid as gray dots
    plt.scatter(data['X-Coordinate_Adjusted'] * 10, data['Y-Coordinate_Adjusted'] * 10, color='gray', label='Grid Points', alpha=0.5)

    for sample in samples:
        iteration += 1
        x, y = sample
        # Convert grid points to adjusted coordinates
        x_adj, y_adj = int(x), int(y)

        # Check if the sampled point is a corrosion point
        sample_data = data[(data['X-Coordinate_Adjusted'] == x_adj) & (data['Y-Coordinate_Adjusted'] == y_adj)]
        if not sample_data.empty and sample_data['Label'].iloc[0] == 1:
            corrosion_found = True
            plt.scatter(x_adj * 10, y_adj * 10, color='red', label='Corrosion Point' if iteration == 1 else "", s=100, edgecolors='black')
            print(f"Corrosion found at iteration {iteration} at grid coordinates ({x_adj}, {y_adj})")
            break
        else:
            plt.scatter(x_adj * 10, y_adj * 10, color='blue', label='Sampled Point' if iteration == 1 else "", alpha=0.7)

    plt.legend()
    plt.show()

    if not corrosion_found:
        print("No corrosion found within the sampled points.")

    return iteration, corrosion_found

# Perform iterative LHS and detect corrosion with plot
iterations_required, corrosion_found = iterative_lhs_corrosion_detection_and_plot(experiment_17_data, n_samples_total)

if corrosion_found:
    print(f"Corrosion was detected after {iterations_required} iterations.")
else:
    print("Corrosion was not detected within the specified number of iterations.")
# Out:
# C:\Users\gzia\AppData\Local\Temp\ipykernel_11684\256700018.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   experiment_17_data['X-Coordinate_Adjusted'] = (experiment_17_data['X-Coordinate'] / 10).round().astype(int)
# C:\Users\gzia\AppData\Local\Temp\ipykernel_11684\256700018.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   experiment_17_data['Y-Coordinate_Adjusted'] = (experiment_17_data['Y-Coordinate'] / 10).round().astype(int)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
rf_gpr_data = np.array([3, 4, 7, 1, 1, 3, 1, 4, 2, 2, 1, 2, 4, 4, 1, 2, 1, 1, 1, 1, 2, 1, 2, 4, 1, 1, 1, 1, 4, 1])
lr_gpr_data = np.array([1, 1, 1, 2, 1, 1, 1, 2, 2, 2, 3, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2])
random_sampling_data = np.array([9, 18, 9, 2, 7, 4, 10, 15, 10, 11, 5, 2, 31, 39, 22, 6, 17, 29, 9, 4, 6, 19, 21, 1, 8, 41, 8, 3, 1, 20])
lhs_sampling_data = np.array([27, 4, 24, 6, 6, 11, 20, 31, 1, 20, 9, 12, 6, 8, 28,25, 5, 16,  38, 8, 13, 5 , 46, 4, 24, 9, 8, 32, 26, 5])

# Calculate the 50% and 90% quantiles for each dataset
quantiles_rf_gpr = np.quantile(rf_gpr_data, [0.5, 0.9])
quantiles_lr_gpr = np.quantile(lr_gpr_data, [0.5, 0.9])
quantiles_random_sampling = np.quantile(random_sampling_data, [0.5, 0.9])
quantiles_lhs_sampling = np.quantile(lhs_sampling_data, [0.5, 0.9])

quantiles_rf_gpr, quantiles_lr_gpr, quantiles_random_sampling, quantiles_lhs_sampling

# Define the bins for the histogram
bins = range(0, max(max(rf_gpr_data), max(lr_gpr_data), max(random_sampling_data), max(lhs_sampling_data)) + 2)

# Plot the histograms
plt.figure(figsize=(14, 7))

# RF+GPR
plt.hist(rf_gpr_data, bins=bins, alpha=0.5, label='RF+GPR')

# LR+GPR
plt.hist(lr_gpr_data, bins=bins, alpha=0.5, label='LR+GPR')

# Random Sampling
plt.hist(random_sampling_data, bins=bins, alpha=0.5, label='Random Sampling')

# Random Sampling
plt.hist(quantiles_lhs_sampling, bins=bins, alpha=0.5, label='LHS Sampling')

# Quantiles for RF+GPR
plt.axvline(quantiles_rf_gpr[0], color='blue', linestyle='dashed', linewidth=2, label='RF+GPR 50% quantile')
plt.axvline(quantiles_rf_gpr[1], color='blue', linestyle='dotted', linewidth=2, label='RF+GPR 90% quantile')

# Quantiles for LR+GPR
plt.axvline(quantiles_lr_gpr[0], color='orange', linestyle='dashed', linewidth=2, label='LR+GPR 50% quantile')
plt.axvline(quantiles_lr_gpr[1], color='orange', linestyle='dotted', linewidth=2, label='LR+GPR 90% quantile')

# Quantiles for Random Sampling
plt.axvline(quantiles_random_sampling[0], color='green', linestyle='dashed', linewidth=2, label='Random Sampling 50% quantile')
plt.axvline(quantiles_random_sampling[1], color='green', linestyle='dotted', linewidth=2, label='Random Sampling 90% quantile')

plt.axvline(quantiles_lhs_sampling[0], color='blue', linestyle='dashed', linewidth=2, label='LHS 50% quantile')
plt.axvline(quantiles_lhs_sampling[1], color='blue', linestyle='dotted', linewidth=2, label='LHS 90% quantile')
# Labels and Title
plt.xlabel('Development Cycles')
plt.ylabel('Frequency')
plt.title('Distribution of Iterations Until Corrosion Detection')
plt.legend()
plt.savefig('distribution_plot.png', dpi=300)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
rf_gpr_data = np.array([7, 8, 11, 5, 5, 5, 5, 9, 7, 7, 5, 7, 8, 8, 5, 7, 5, 5, 5, 5, 7, 5, 7, 8, 5, 5, 5, 5, 8, 5])
lr_gpr_data = np.array([5, 5, 5, 7, 5, 5, 5, 7, 6, 6, 7, 5, 5, 5, 5, 6, 5, 5, 5, 6, 5, 7, 6, 5, 6, 6, 6, 6, 6, 6])
random_sampling_data = np.array([9, 18, 9, 2, 7, 4, 10, 15, 10, 11, 5, 2, 31, 39, 22, 6, 17, 29, 9, 4, 6, 19, 21, 1, 8, 41, 8, 3, 1, 20])
lhs_sampling_data = np.array([27, 4, 24, 6, 6, 11, 20, 31, 1, 20, 9, 12, 6, 8, 28, 25, 5, 16, 38, 8, 13, 5, 46, 4, 24, 9, 8, 32, 26, 5])

# Calculate the 90% quantile for each dataset
quantile_90_rf_gpr = np.quantile(rf_gpr_data, 0.9)
quantile_90_lr_gpr = np.quantile(lr_gpr_data, 0.9)
quantile_90_random_sampling = np.quantile(random_sampling_data, 0.9)
quantile_90_lhs_sampling = np.quantile(lhs_sampling_data, 0.9)

# Method names
methods = ['RF+GPR', 'LR+GPR', 'Random Sampling', 'LHS Sampling']

# 90% Quantile values
quantile_90_values = [quantile_90_rf_gpr, quantile_90_lr_gpr, quantile_90_random_sampling, quantile_90_lhs_sampling]

# Create the bar diagram
plt.figure(figsize=(10, 6))
plt.bar(methods, quantile_90_values, color=['blue', 'orange', 'green', 'red'])

# Adding the text labels on the bars
for i, value in enumerate(quantile_90_values):
    plt.text(i, value + 0.5, f"{value:.2f}", ha='center')

# Labels and Title
plt.ylabel('90% Performance Quantile (Development Cycles)')
plt.title('Comparison of 90% Performance Quantile Across Sampling Methods')
plt.ylim(0, max(quantile_90_values) + 2)  # Adjust y-axis limit to fit the text labels

# Show the plot
plt.savefig('quantile_90_performance_comparison.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
rf_gpr_data = np.array([7, 8, 11, 5, 5, 5, 5, 9, 7, 7, 5, 7, 8, 8, 5, 7, 5, 5, 5, 5, 7, 5, 7, 8, 5, 5, 5, 5, 8, 5])
lr_gpr_data = np.array([5, 5, 5, 7, 5, 5, 5, 7, 6, 6, 7, 5, 5, 5, 5, 6, 5, 5, 5, 6, 5, 7, 6, 5, 6, 6, 6, 6, 6, 6])
random_sampling_data = np.array([9, 18, 9, 2, 7, 4, 10, 15, 10, 11, 5, 2, 31, 39, 22, 6, 17, 29, 9, 4, 6, 19, 21, 1, 8, 41, 8, 3, 1, 20])

# Replace lhs_sampling_data with the mean of the minimum and maximum of the desired range
grid_sampling_data = np.mean([1, 117])  # Mean of the range 1 to 117

# Calculate the 90% quantile for each dataset
quantile_90_rf_gpr = np.quantile(rf_gpr_data, 0.9)
quantile_90_lr_gpr = np.quantile(lr_gpr_data, 0.9)
quantile_90_random_sampling = np.quantile(random_sampling_data, 0.9)

# Method names
methods = ['RF+GPR', 'LR+GPR', 'Random Sampling', '9x13 Grid Measurement']

# 90% Quantile values
quantile_90_values = [quantile_90_rf_gpr, quantile_90_lr_gpr, quantile_90_random_sampling, grid_sampling_data]

# Create the bar diagram
plt.figure(figsize=(10, 6))
bars = plt.bar(methods, quantile_90_values, color=['blue', 'orange', 'green', 'red'])

# Add error bar to represent the range for LHS Sampling
# Add error bar to represent the range for LHS Sampling
# Reshape yerr to be a 2x1 array to match the single y value for LHS Sampling
plt.errorbar(methods[-1], lhs_sampling_mean, yerr=[[lhs_sampling_mean-1], [117-lhs_sampling_mean]], fmt='o', color='black', capsize=5)

# Adding the text labels on the bars
for i, value in enumerate(quantile_90_values):
    plt.text(i, value + (5 if i == 3 else 0.5), f"{value:.2f}", ha='center')

# Labels and Title
# Labels and Title
plt.ylabel('Corrosion Detection Performance (90% Quantile)')
plt.title('Comparative Analysis of Corrosion Detection Across Sampling Methods')

plt.ylim(0, max(quantile_90_values) + 10)  # Adjust y-axis limit to fit the range representation

# Show the plot
plt.savefig('quantile_90_performance_comparison.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
rf_gpr_data = np.array([7, 8, 11, 5, 5, 5, 5, 9, 7, 7, 5, 7, 8, 8, 5, 7, 5, 5, 5, 5, 7, 5, 7, 8, 5, 5, 5, 5, 8, 5])
lr_gpr_data = np.array([5, 5, 5, 7, 5, 5, 5, 7, 6, 6, 7, 5, 5, 5, 5, 6, 5, 5, 5, 6, 5, 7, 6, 5, 6, 6, 6, 6, 6, 6])
random_sampling_data = np.array([9, 18, 9, 2, 7, 4, 10, 15, 10, 11, 5, 2, 31, 39, 22, 6, 17, 29, 9, 4, 6, 19, 21, 1, 8, 41, 8, 3, 1, 20])

# Value for 9x13 Grid Measurement, set to maximum of the range
grid_sampling_max = 117  # Maximum of the range 1 to 117

# Calculate the 90% quantile for each dataset
quantile_90_rf_gpr = np.quantile(rf_gpr_data, 0.9)
quantile_90_lr_gpr = np.quantile(lr_gpr_data, 0.9)
quantile_90_random_sampling = np.quantile(random_sampling_data, 0.9)

# Method names
methods = ['RF+GPR', 'LR+GPR', 'Random Sampling', '9x13 Grid Measurement']

# Values for each method, using the maximum value for 9x13 Grid Measurement
values = [quantile_90_rf_gpr, quantile_90_lr_gpr, quantile_90_random_sampling, grid_sampling_max]

# Create the bar diagram
plt.figure(figsize=(10, 6))
plt.bar(methods, values, color=['lightgreen', 'orange', 'skyblue', 'SlateBlue'])



# Adding the text labels on the bars
for i, value in enumerate(values):
    plt.text(i, value + 5, f"{value:.2f}", ha='center')

# Labels and Title
plt.ylabel('Corrosion Detection Performance')
plt.title('Comparative Analysis of Corrosion Detection Across Sampling Methods')

plt.ylim(0, max(values) + 10)  # Adjust y-axis limit to fit the labels
plt.savefig('quantile_90_performance_comparison.png', dpi=300)

# Show the plot
plt.show()

# %%
import numpy as np

rf_gpr_data = np.array([7, 8, 11, 5, 5, 5, 5, 9, 7, 7, 5, 7, 8, 8, 5, 7, 5, 5, 5, 5, 7, 5, 7, 8, 5, 5, 5, 5, 8, 5])

mean_value = np.mean(rf_gpr_data)
std_dev = np.std(rf_gpr_data)

mean_value, std_dev
# Out:
# (6.3, 1.5737428845483834)

# %%
import numpy as np

lr_gpr_data = np.array([5, 5, 5, 7, 5, 5, 5, 7, 6, 6, 7, 5, 5, 5, 5, 6, 5, 5, 5, 6, 5, 7, 6, 5, 6, 6, 6, 6, 6, 6])

mean_value = np.mean(lr_gpr_data)
std_dev = np.std(lr_gpr_data)

mean_value, std_dev
# Out:
# (5.633333333333334, 0.706320670013903)

# %%
import numpy as np

grid_data =117

mean_value = np.mean(grid_data)
std_dev = np.std(grid_data)

mean_value, std_dev
# Out:
# (117.0, 0.0)
