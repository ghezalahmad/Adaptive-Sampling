# %% [markdown]
# ### Experiment

# %%
### Using Unbalanced Dataset - LR on Experiment 17

sample_list_unbalanced_Experiement17 = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
iteration_list = [2, 1, 1, 1, 2, 1, 3, 1, 1, 2]

# %%
### Using balanced Dataset - LR on Experiment 17

sample_list_balanced_Experiement17 = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
iteration_list = [1, 1, 1, 1, 2, 2, 1, 1, 1, 1]

# %%
### Using Unbalanced Dataset - LR on Experiment 18

sample_list_Unbalanced_Experiement18 = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
iteration_list = [2, 6, 1, 1, 2, 5, 3, 2, 4, 1]

# %%
### Using balanced Dataset - LR on Experiment 18

sample_list_balanced_Experiement18 = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
iteration_list = [1, 1, 1, 1, 1, 4, 1, 2, 5, 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
# Data for the combined plot
sample_sizes = np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])

# Iterations for each experiment and dataset
iterations_17_unbalanced = np.array([2, 1, 1, 1, 2, 1, 3, 1, 1, 2])
iterations_17_balanced = np.array([1, 1, 1, 1, 2, 2, 1, 1, 1, 1])
iterations_18_unbalanced = np.array([2, 6, 1, 1, 2, 5, 3, 2, 4, 1])
iterations_18_balanced = np.array([1, 1, 1, 1, 1, 4, 1, 2, 5, 3])

# Width of the bars
bar_width = 0.2

# Positions of the bar groups
r1 = np.arange(len(sample_sizes))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Creating the combined plot
plt.figure(figsize=(15, 8))

plt.bar(r1, iterations_17_unbalanced, color='blue', width=bar_width, edgecolor='grey', label='Experiment 17 - Unbalanced')
plt.bar(r2, iterations_17_balanced, color='green', width=bar_width, edgecolor='grey', label='Experiment 17 - Balanced')
plt.bar(r3, iterations_18_unbalanced, color='red', width=bar_width, edgecolor='grey', label='Experiment 18 - Unbalanced')
plt.bar(r4, iterations_18_balanced, color='orange', width=bar_width, edgecolor='grey', label='Experiment 18 - Balanced')

# Adding labels and title
plt.xlabel('Sample Size', fontweight='bold')
plt.ylabel('Number of Iterations', fontweight='bold')
plt.xticks([r + bar_width for r in range(len(sample_sizes))], sample_sizes)
plt.title('Comparative Bar Plot for Experiments 17 & 18 using LR')

# Creating the legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Benchmarking RF for Experiement 17 & 18

# %%
import numpy as np
import matplotlib.pyplot as plt
# Data for the combined plot
sample_sizes = np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])

# Iterations for each experiment and dataset
iterations_17_unbalanced = np.array([1, 1, 1, 2, 2, 3, 1, 1, 2, 1])
iterations_17_balanced = np.array([1, 2, 1, 1, 2, 2, 2, 2, 1, 2])
iterations_18_unbalanced = np.array([2, 8, 5, 1, 5, 2, 1, 6, 4, 6])
iterations_18_balanced = np.array([1, 3, 1, 2, 3, 1, 4, 4, 5, 4])

# Width of the bars
bar_width = 0.2

# Positions of the bar groups
r1 = np.arange(len(sample_sizes))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Creating the combined plot
plt.figure(figsize=(15, 8))

plt.bar(r1, iterations_17_unbalanced, color='blue', width=bar_width, edgecolor='grey', label='Experiment 17 - Unbalanced')
plt.bar(r2, iterations_17_balanced, color='green', width=bar_width, edgecolor='grey', label='Experiment 17 - Balanced')
plt.bar(r3, iterations_18_unbalanced, color='red', width=bar_width, edgecolor='grey', label='Experiment 18 - Unbalanced')
plt.bar(r4, iterations_18_balanced, color='orange', width=bar_width, edgecolor='grey', label='Experiment 18 - Balanced')

# Adding labels and title
plt.xlabel('Sample Size', fontweight='bold')
plt.ylabel('Number of Iterations', fontweight='bold')
plt.xticks([r + bar_width for r in range(len(sample_sizes))], sample_sizes)
plt.title('Comparative Bar Plot for Experiments 17 & 18 using RF')

# Creating the legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
